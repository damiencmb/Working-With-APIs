# %% [markdown]
# # Use this notebook for your 3 choices of APIs

# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

# %% [markdown]
# ## Dog Facts API (doc: https://kinduff.github.io/dog-api/)
# This dataset brings joy, so it could be used for self-care/curiosity projects because it feels nice to read about dogs.

# %%
res = requests.get('http://dog-api.kinduff.com/api/facts?number=1000')

# %%
res.status_code
# Out:
# 200

# %%
df = res.json()
# df

# %%
df = pd.DataFrame(df)
df
# Out:
#                                                 facts  success
# 0   Here’s looking at you. Dogs have three eyelids...     True
# 1       The Basenji is the world’s only barkless dog.     True
# 2   When "Bobbie," a Collie/Shepherd mix, was acci...     True
# 3   Small quantities of grapes and raisins can cau...     True
# 4                Davy Crockett had a dog named Sport.     True
# ..                                                ...      ...
# 95  Dogs can be trained to detect cancer and other...     True
# 96  Wow, check out those choppers! Puppies have 28...     True
# 97  Pitter patter. A large breed dog’s resting hea...     True
# 98  Weird dog laws include allowing police offers ...     True
# 99  Dogs are naturally submissive to any creature ...     True
#
# [100 rows x 2 columns]

# %%
import random

def random_dogfact(data):
    print(data['facts'][random.randint(0, len(data)-1)])

random_dogfact(df)
# Out:
# A Beatles hit. It’s rumored that, at the end of the Beatles song, "A Day in the Life," Paul McCartney recorded an ultrasonic whistle, audible only to dogs, just for his Shetland sheepdog.

# %% [markdown]
# ## Hyrule compendium API (doc: https://gadhagod.github.io/Hyrule-Compendium-API/#/)
# This compendium covers all items that Link (the player) can interact with in the game, from all sorts of creatures and monsters to treasures. This can be used for a guide to players who are having a hard time completing the game; looking into the structure and seeing potential monster item drops or treasure locations, this information can be used to create a list of daily outcome-focused tasks to help players reach their goals in levelling up their skills and toolkit for the story.

# %%
res = requests.get('https://botw-compendium.herokuapp.com/api/v3/compendium/all')

# %%
res.status_code
# Out:
# 200

# %%
df = res.json()
# df

# %%
df = json_normalize(df['data'])
df
# Out:
# /var/folders/7j/l1wcl8z56w9bsr_12qmb6hrm0000gn/T/ipykernel_17592/2568688740.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(df['data'])
#       category                          common_locations  \
# 0     treasure                          [Greater Hyrule]
# 1     treasure                          [Greater Hyrule]
# 2     treasure                          [Greater Hyrule]
# 3     treasure                          [Greater Hyrule]
# 4     monsters      [Eldin Mountains, Tabantha Frontier]
# ..         ...                                       ...
# 384  creatures  [Tabantha Frontier, Great Hyrule Forest]
# 385  creatures       [Hyrule Ridge, Great Hyrule Forest]
# 386  creatures                         [Satori Mountain]
# 387  creatures                 [Necluda Sea, Akkala Sea]
# 388  creatures                           [Gerudo Desert]
#
#                                            description    dlc  \
# 0    This deposit contains a good deal of precious ...  False
# 1    This deposit contains quite a bit of luminous ...  False
# 2    This deposit contains a good deal of ore. Brea...  False
# 3    Fortunes untold (potentially) await the lucky ...  False
# 4    A spirit of fire has taken the form of this gi...  False
# ..                                                 ...    ...
# 384  These wolves are not only carnivorous but can ...  False
# 385  These herbivores make their home in meadows an...  False
# 386  This noble creature watches over all animals t...  False
# 387  These birds live near the ocean. They eat main...  False
# 388  This desert-dwelling breed of sparrow has adap...  False
#
#                                                  drops   id  \
# 0       [ruby, sapphire, diamond, amber, topaz, flint]  388
# 1                                    [luminous, flint]  389
# 2    [ruby, diamond, amber, sapphire, topaz, opal, ...  387
# 3                                          [treasures]  386
# 4                                                 None  153
# ..                                                 ...  ...
# 384                 [raw prime meat, raw gourmet meat]   21
# 385                                         [raw meat]   12
# 386                                               None    4
# 387                               [raw bird drumstick]   45
# 388                               [chickaloo tree nut]   34
#
#                                                  image                  name  \
# 0    https://botw-compendium.herokuapp.com/api/v3/c...      rare ore deposit
# 1    https://botw-compendium.herokuapp.com/api/v3/c...  luminous ore deposit
# 2    https://botw-compendium.herokuapp.com/api/v3/c...           ore deposit
# 3    https://botw-compendium.herokuapp.com/api/v3/c...        treasure chest
# 4    https://botw-compendium.herokuapp.com/api/v3/c...               dinraal
# ..                                                 ...                   ...
# 384  https://botw-compendium.herokuapp.com/api/v3/c...          maraudo wolf
# 385  https://botw-compendium.herokuapp.com/api/v3/c...         mountain goat
# 386  https://botw-compendium.herokuapp.com/api/v3/c...  lord of the mountain
# 387  https://botw-compendium.herokuapp.com/api/v3/c...               seagull
# 388  https://botw-compendium.herokuapp.com/api/v3/c...          sand sparrow
#
#     cooking_effect  hearts_recovered  properties.attack  properties.defense  \
# 0              NaN               NaN                NaN                 NaN
# 1              NaN               NaN                NaN                 NaN
# 2              NaN               NaN                NaN                 NaN
# 3              NaN               NaN                NaN                 NaN
# 4              NaN               NaN                NaN                 NaN
# ..             ...               ...                ...                 ...
# 384            NaN               NaN                NaN                 NaN
# 385            NaN               NaN                NaN                 NaN
# 386            NaN               NaN                NaN                 NaN
# 387            NaN               NaN                NaN                 NaN
# 388            NaN               NaN                NaN                 NaN
#
#     edible
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 384  False
# 385  False
# 386  False
# 387  False
# 388  False
#
# [389 rows x 13 columns]

# %% [markdown]
# ## Most wanted by FBI API (doc: https://www.fbi.gov/wanted/api)
# Since this is a single page of profiles, we could use a for loop to iterate over the number of pages to get even more information of these individuals. Aside from general population awareness, this API could be useful for a project evaluating personal factors in most wanted profiles, like their professions or age, to potentially correlate factors into these actions warranting them to be on this list.

# %%
res = requests.get('https://api.fbi.gov/wanted/v1/list')

# %%
res.status_code
# Out:
# 200

# %%
df = res.json()
# df

# %%
flattened_data = json_normalize(df['items'])

flattened_data
# Out:
# /var/folders/7j/l1wcl8z56w9bsr_12qmb6hrm0000gn/T/ipykernel_17592/2174259808.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(df['items'])
#                                                 files  \
# 0   [{'url': 'https://www.fbi.gov/wanted/additiona...
# 1   [{'url': 'https://www.fbi.gov/wanted/terrorinf...
# 2   [{'url': 'https://www.fbi.gov/wanted/terrorinf...
# 3   [{'url': 'https://www.fbi.gov/wanted/murders/r...
# 4   [{'url': 'https://www.fbi.gov/wanted/additiona...
# 5   [{'url': 'https://www.fbi.gov/wanted/vicap/mis...
# 6   [{'url': 'https://www.fbi.gov/wanted/vicap/uni...
# 7   [{'url': 'https://www.fbi.gov/wanted/vicap/mis...
# 8   [{'url': 'https://www.fbi.gov/wanted/dt/leo-fr...
# 9   [{'url': 'https://www.fbi.gov/wanted/kidnap/pa...
# 10  [{'url': 'https://www.fbi.gov/wanted/wcc/volod...
# 11  [{'url': 'https://www.fbi.gov/wanted/seeking-i...
# 12  [{'url': 'https://www.fbi.gov/wanted/kidnap/br...
# 13  [{'url': 'https://www.fbi.gov/wanted/parental-...
# 14  [{'url': 'https://www.fbi.gov/wanted/parental-...
# 15  [{'url': 'https://www.fbi.gov/wanted/seeking-i...
# 16  [{'url': 'https://www.fbi.gov/wanted/known-ban...
# 17  [{'url': 'https://www.fbi.gov/wanted/additiona...
# 18  [{'url': 'https://www.fbi.gov/wanted/seeking-i...
# 19  [{'url': 'https://www.fbi.gov/wanted/cei/isaia...
#
#                                 age_range                               uid  \
# 0                                    None  10be2609948b45e6bedc827469219051
# 1                                    None  33d7bb2bf6de41cb9ce05f7250c065d0
# 2                                    None  8c7abfbd01eb4017a64717a0b6060939
# 3                                    None  83a7764745a647a8b37fdab212c6c81b
# 4                                    None  777ceebf76c14fd7aa8f3ced4f98be76
# 5   24 years old at time of disappearance  6821fa45714045a186f52c84db67ae72
# 6   30 to 50 years old (at time of death)  9dc24203f49b46419d6cd4f1a434ec5a
# 7                   17 (time of incident)  70eaa8aa5d454c678fd918af3a185e24
# 8                                    None  976d4ddb72ba332b23a1b2480b000e0d
# 9                                    None  357791ddd4a04f6392beee551cf36d74
# 10                                   None  3392bb76724f44359908eb700ee7b9b3
# 11                                   None  6198ab8dd9584d7e917e371ec29d9e22
# 12                                   None  4d07360c63d948d788166e0f6e6febd2
# 13                                   None  9e5ed833ea9543c8b06cfdf2a610876c
# 14                                   None  c80b6cafc33d4e48a13547303c061993
# 15                                   None  b21a191b31aa4875adab0e45f55d7ef1
# 16                                   None  30aba11b2ee64ce2bd77413cd5889507
# 17                                   None  fad7548c4017492bb31339b961e02da2
# 18                                   None  23bb27f8c9684ee1a8fa632d9b0f67ff
# 19                                   None  68d2d497d75d4fd1bb118068591de197
#
#                                           weight  \
# 0                                     155 pounds
# 1                                           None
# 2                                           None
# 3                                     190 pounds
# 4                                     280 pounds
# 5                                     110 pounds
# 6                              110 to 140 pounds
# 7                              115 to 125 pounds
# 8                                     185 pounds
# 9                                     150 pounds
# 10                             240 to 280 pounds
# 11                                    180 pounds
# 12          33 pounds (at time of disappearance)
# 13  85 pounds (At the time of her disappearance)
# 14                                    110 pounds
# 15                                          None
# 16                                    130 pounds
# 17                                    190 pounds
# 18                                          None
# 19               Approximately 125 to 144 pounds
#
#                                           occupations  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3   [Surgical Catheter Technician, Respiratory The...
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                              [Laborer and watchman]
# 9   [Paula Ann Wade was working for Sam's Club at ...
# 10         [Property repair and maintenance manager.]
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
#
#                  field_offices locations  \
# 0   [losangeles, washingtondc]      None
# 1                 [losangeles]      None
# 2                 [losangeles]      None
# 3                    [phoenix]      None
# 4        [tampa, washingtondc]      None
# 5                         None      None
# 6                         None      None
# 7                         None      None
# 8                  [milwaukee]      None
# 9                    [atlanta]      None
# 10                   [seattle]      None
# 11                    [boston]      None
# 12                   [atlanta]      None
# 13                  [columbia]      None
# 14                  [columbia]      None
# 15                  [portland]      None
# 16                   [stlouis]      None
# 17                   [seattle]      None
# 18                   [newyork]      None
# 19               [albuquerque]      None
#
#                                           reward_text     sex   hair  ...  \
# 0                                                None    Male  brown  ...
# 1   The FBI is offering a reward of up to $20,000 ...  Female   None  ...
# 2   The FBI is offering a reward of up to $20,000 ...    Male  black  ...
# 3                                                None    Male  brown  ...
# 4                                                None    Male  brown  ...
# 5                                                None  Female  brown  ...
# 6                                                None  Female  brown  ...
# 7                                                None  Female  blond  ...
# 8   The FBI is offering a reward of up to $150,000...    Male  brown  ...
# 9                                                None  Female  brown  ...
# 10                                               None    Male  blond  ...
# 11  The FBI is offering a reward of up to $10,000 ...    Male  brown  ...
# 12                                               None    Male  brown  ...
# 13                                               None  Female  brown  ...
# 14                                               None  Female  brown  ...
# 15  The FBI is offering a reward of up to $15,000 ...    None   None  ...
# 16                                               None    Male  black  ...
# 17                                               None    Male  black  ...
# 18  The FBI is offering a reward of up to $10,000 ...    None   None  ...
# 19                                               None    Male  black  ...
#
#                  possible_states                   modified reward_max  \
# 0                           None  2023-09-05T23:02:50+00:00          0
# 1                           None  2023-09-05T17:10:21+00:00          0
# 2                           None  2023-09-05T17:08:50+00:00          0
# 3                           None  2023-09-05T00:00:24+00:00          0
# 4                           None  2023-09-05T00:00:23+00:00          0
# 5                           None  2023-09-05T00:00:22+00:00          0
# 6                           None  2023-09-05T00:00:22+00:00          0
# 7                           None  2023-09-02T21:46:10+00:00          0
# 8   [US-MA, US-NY, US-PA, US-WI]  2023-08-31T18:14:51+00:00     999999
# 9                           None  2023-08-29T19:23:38+00:00          0
# 10                          None  2023-08-28T17:41:20+00:00          0
# 11                          None  2023-08-24T13:11:48+00:00          0
# 12                          None  2023-08-23T16:36:48+00:00          0
# 13                          None  2023-08-16T17:49:38+00:00          0
# 14                          None  2023-08-16T17:47:38+00:00          0
# 15                          None  2023-08-15T19:00:55+00:00          0
# 16                          None  2023-08-15T16:49:04+00:00          0
# 17                          None  2023-08-15T12:53:20+00:00          0
# 18                          None  2023-08-14T13:44:22+00:00          0
# 19                          None  2023-08-14T12:28:25+00:00          0
#
#         race  height_max         place_of_birth height_min  \
# 0      white        72.0                   None       72.0
# 1       None         NaN                  Egypt        NaN
# 2       None         NaN                  Egypt        NaN
# 3      white        72.0     Brooklyn, New York       72.0
# 4      white        75.0               New York       75.0
# 5      white        58.0                   None       58.0
# 6      white         NaN                   None        NaN
# 7      white        63.0                   None       62.0
# 8      white        72.0    Darby, Pennsylvania       71.0
# 9      white        67.0                   None       67.0
# 10     white        74.0                Ukraine       74.0
# 11     white        69.0  Boston, Massachusetts       69.0
# 12     white        33.0                   None       33.0
# 13     white        56.0                   None       56.0
# 14     white        63.0       Elkton, Maryland       63.0
# 15      None         NaN                   None        NaN
# 16     black        66.0               Missouri       66.0
# 17    native        66.0             Washington       66.0
# 18      None         NaN                   None        NaN
# 19  hispanic        68.0             New Mexico       67.0
#
#    poster_classification                                    warning_message  \
# 0                default                                               None
# 1            information                                               None
# 2            information                                               None
# 3                default  SHOULD BE CONSIDERED ARMED AND EXTREMELY DANGE...
# 4                default                                               None
# 5                default                                               None
# 6                default                                               None
# 7                default                                               None
# 8                default           SHOULD BE CONSIDERED ARMED AND DANGEROUS
# 9                missing                                               None
# 10               default           SHOULD BE CONSIDERED ARMED AND DANGEROUS
# 11           information                                               None
# 12               missing                                               None
# 13            kidnapping                                               None
# 14               default                                               None
# 15           information                                               None
# 16               default  SHOULD BE CONSIDERED ARMED AND DANGEROUS AND M...
# 17               default                                               None
# 18           information                                               None
# 19               default  SHOULD BE CONSIDERED ARMED AND DANGEROUS AND A...
#
#                                                   @id
# 0   https://api.fbi.gov/@wanted-person/10be2609948...
# 1   https://api.fbi.gov/@wanted-person/33d7bb2bf6d...
# 2   https://api.fbi.gov/@wanted-person/8c7abfbd01e...
# 3   https://api.fbi.gov/@wanted-person/83a7764745a...
# 4   https://api.fbi.gov/@wanted-person/777ceebf76c...
# 5   https://api.fbi.gov/@wanted-person/6821fa45714...
# 6   https://api.fbi.gov/@wanted-person/9dc24203f49...
# 7   https://api.fbi.gov/@wanted-person/70eaa8aa5d4...
# 8   https://api.fbi.gov/@wanted-person/976d4ddb72b...
# 9   https://api.fbi.gov/@wanted-person/357791ddd4a...
# 10  https://api.fbi.gov/@wanted-person/3392bb76724...
# 11  https://api.fbi.gov/@wanted-person/6198ab8dd95...
# 12  https://api.fbi.gov/@wanted-person/4d07360c63d...
# 13  https://api.fbi.gov/@wanted-person/9e5ed833ea9...
# 14  https://api.fbi.gov/@wanted-person/c80b6cafc33...
# 15  https://api.fbi.gov/@wanted-person/b21a191b31a...
# 16  https://api.fbi.gov/@wanted-person/30aba11b2ee...
# 17  https://api.fbi.gov/@wanted-person/fad7548c401...
# 18  https://api.fbi.gov/@wanted-person/23bb27f8c96...
# 19  https://api.fbi.gov/@wanted-person/68d2d497d75...
#
# [20 rows x 54 columns]
